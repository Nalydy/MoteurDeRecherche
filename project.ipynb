# %% [markdown]
# # TP Text Mining

# %%
# Connecteur

class Document:
    def __init__(self, url, text):
        self.url_ = url
        self.text_ = text

# %%
import os

def fetch(path, recursive=True):
    files = []
    # r=root, d=directories, f = files
    if (recursive):
        for r, d, f in os.walk(path):
            for file in f:
                files.append(os.path.join(r, file))
    else:
        files = [ f for f in os.listdir('.') if os.path.isfile(os.path.join('.',f)) ]
    
    #print(files)
    documents = []
    for file in files:
        try:
            if not file.endswith(".ipynb"):
                txt = open(file, "r").read()
                documents.append(Document(file, txt))
        except:
            pass
    return documents

# %%
data_documents = fetch("./", True)

# %%
class TokenizedDocument:
    def __init__(self, url, words):
        self.url_ = url
        self.words_ = words

# %%
class Processor():
    def process(self, word):
        raise Exception("This is an abstract class : %s" %cls)

# %%
import unicodedata
class Normalizer(Processor):
    def process(self, word):
        uni = unicodedata.normalize('NFD', word).encode('ascii', 'ignore').lower()
        return str(uni, 'utf-8')

# %%
norm = Normalizer()
norm.process('Télécharger c"est mal')
# Out:
# 'telecharger c"est mal'

# %%
import re
def analyze(documents, processors):
    tokenizedDocs = []
    for doc in documents:
        words = re.findall(r"[\w']+", doc.text_)
        for processor in processors:
            words = [processor.process(w) for w in words]
        tokenizedDocs.append(TokenizedDocument(doc.url_, words))
    return tokenizedDocs

# %%
sample_doc = data_documents[:2]
norm = Normalizer()
sample_tokenized_doc = analyze(sample_doc, [norm])
sample_tokenized_doc[1].url_, sample_tokenized_doc[1].words_
# Out:
# ('./20news-bydate-test/alt.atheism/53639',
#  ['from',
#   'mandtbacka',
#   'finabo',
#   'abo',
#   'fi',
#   'mats',
#   'andtbacka',
#   'subject',
#   're',
#   'after',
#   '2000',
#   'years',
#   'can',
#   'we',
#   'say',
#   'that',
#   'christian',
#   'morality',
#   'is',
#   'in',
#   'reply',
#   'to',
#   'frank',
#   'd012s658',
#   "uucp's",
#   'message',
#   'of',
#   '21',
#   'apr',
#   '1993',
#   '09',
#   '38',
#   '43',
#   'gmt',
#   'organization',
#   'unorganized',
#   'usenet',
#   'postings',
#   'uninc',
#   'x',
#   'news',
#   'reader',
#   'vms',
#   'news',
#   '1',
#   '24',
#   'lines',
#   '151',
#   'in',
#   '1r34n3',
#   'hfj',
#   'horus',
#   'ap',
#   'mchp',
#   'sni',
#   'de',
#   'frank',
#   'd012s658',
#   'uucp',
#   'writes',
#   'deletia',
#   'in',
#   'case',
#   'anybody',
#   "hadn't",
#   'noticed',
#   'frank',
#   'and',
#   'i',
#   'are',
#   'debating',
#   'objective',
#   'morality',
#   'and',
#   'seemingly',
#   'hitting',
#   'semantics',
#   'secondly',
#   'how',
#   'can',
#   'i',
#   'refute',
#   'your',
#   'definition',
#   'i',
#   'can',
#   'only',
#   'point',
#   'up',
#   'its',
#   'logical',
#   'implications',
#   'and',
#   'say',
#   'that',
#   'they',
#   'seem',
#   'to',
#   'contradict',
#   'the',
#   'usage',
#   'of',
#   'the',
#   'word',
#   'objective',
#   'in',
#   'other',
#   'areas',
#   'indeed',
#   'by',
#   'your',
#   'definition',
#   'an',
#   'objective',
#   'x',
#   'is',
#   'an',
#   'oxymoron',
#   'for',
#   'all',
#   'x',
#   'i',
#   'have',
#   'no',
#   'quibble',
#   'with',
#   'that',
#   'belief',
#   'other',
#   'than',
#   'that',
#   'it',
#   'is',
#   'useless',
#   'and',
#   'that',
#   'objective',
#   'is',
#   'a',
#   'perfectly',
#   'good',
#   'word',
#   'it',
#   'may',
#   'be',
#   'that',
#   'being',
#   'a',
#   'non',
#   'native',
#   'english',
#   'speaker',
#   "i've",
#   'misunderstood',
#   'your',
#   'usage',
#   'of',
#   'objective',
#   'and',
#   'tried',
#   'to',
#   'debate',
#   'something',
#   'you',
#   "don't",
#   'assert',
#   'my',
#   'apologies',
#   "i'm",
#   'at',
#   'a',
#   'loss',
#   'to',
#   'imagine',
#   'what',
#   'you',
#   'really',
#   'do',
#   'mean',
#   'though',
#   'how',
#   'many',
#   'ages',
#   'can',
#   'the',
#   'universe',
#   'have',
#   'and',
#   'still',
#   'be',
#   'internally',
#   'self',
#   'consistent',
#   "i'd",
#   'be',
#   'amazed',
#   'if',
#   'it',
#   'was',
#   'more',
#   'than',
#   'one',
#   'how',
#   'many',
#   'different',
#   'moral',
#   'systems',
#   'can',
#   'different',
#   'members',
#   'of',
#   'society',
#   'have',
#   'indeed',
#   'single',
#   'individuals',
#   'in',
#   'some',
#   'cases',
#   'and',
#   'humanity',
#   'still',
#   'stick',
#   'together',
#   'begging',
#   'the',
#   'question',
#   'people',
#   'can',
#   'have',
#   'many',
#   'opinions',
#   'about',
#   'the',
#   'age',
#   'of',
#   'the',
#   'universe',
#   'and',
#   'humanity',
#   'can',
#   'still',
#   'stick',
#   'together',
#   'you',
#   'are',
#   'saying',
#   'that',
#   'the',
#   'universe',
#   'has',
#   'a',
#   '_real_',
#   'age',
#   'independent',
#   'of',
#   'my',
#   'beliefs',
#   'about',
#   'it',
#   'why',
#   'wrong',
#   'point',
#   'the',
#   'age',
#   'of',
#   'the',
#   'universe',
#   'has',
#   'no',
#   'direct',
#   'effect',
#   'on',
#   "humanity's",
#   'sticking',
#   'power',
#   'in',
#   'the',
#   'way',
#   'the',
#   'moral',
#   'system',
#   'of',
#   'a',
#   'society',
#   'can',
#   'have',
#   "i'm",
#   'saying',
#   'the',
#   'universe',
#   'has',
#   'a',
#   'real',
#   'age',
#   'because',
#   'i',
#   'see',
#   'evidence',
#   'for',
#   'it',
#   'cosmology',
#   'astronomy',
#   'and',
#   'so',
#   'on',
#   'i',
#   'say',
#   'this',
#   'age',
#   'is',
#   'independent',
#   'of',
#   "people's",
#   'opinions',
#   'of',
#   'it',
#   'because',
#   'i',
#   'know',
#   'different',
#   'people',
#   'have',
#   'a',
#   'lot',
#   'of',
#   'different',
#   'opinions',
#   'in',
#   'the',
#   'matter',
#   'yet',
#   'empirical',
#   'tests',
#   'consistently',
#   'seem',
#   'to',
#   'give',
#   'roughly',
#   'the',
#   'same',
#   'results',
#   'the',
#   'age',
#   'of',
#   'the',
#   'universe',
#   'like',
#   'most',
#   'scientific',
#   'facts',
#   'can',
#   'be',
#   'emirically',
#   'verified',
#   'through',
#   'means',
#   "that'll",
#   'give',
#   'the',
#   'same',
#   'result',
#   'no',
#   'matter',
#   'who',
#   'performs',
#   'the',
#   'testing',
#   'albeit',
#   'there',
#   'are',
#   'error',
#   'bars',
#   'that',
#   'may',
#   'be',
#   'on',
#   'the',
#   'largish',
#   'side',
#   'this',
#   'assumes',
#   'that',
#   'the',
#   'universe',
#   'has',
#   'a',
#   'real',
#   'age',
#   'or',
#   'any',
#   'kind',
#   'of',
#   'reality',
#   'which',
#   "doesn't",
#   'depend',
#   'on',
#   'what',
#   'we',
#   'think',
#   'i',
#   "can't",
#   'see',
#   'how',
#   'it',
#   'does',
#   'that',
#   'put',
#   'a',
#   'creationist',
#   'to',
#   'the',
#   'task',
#   'of',
#   'performing',
#   'the',
#   'tests',
#   'and',
#   'calculations',
#   'see',
#   'to',
#   'it',
#   's',
#   'he',
#   'makes',
#   'no',
#   'blatant',
#   'errors',
#   'in',
#   'measuring',
#   'or',
#   'calculating',
#   'and',
#   'the',
#   'result',
#   'of',
#   'the',
#   'test',
#   'will',
#   'be',
#   'the',
#   'same',
#   'why',
#   'should',
#   'an',
#   'extreme',
#   'biblical',
#   'creationist',
#   'give',
#   'a',
#   "rat's",
#   'ass',
#   'about',
#   'the',
#   'means',
#   'of',
#   'which',
#   'you',
#   'speak',
#   'because',
#   'logically',
#   'consistent',
#   'empirical',
#   'tests',
#   'contradict',
#   'their',
#   'opinion',
#   'if',
#   'those',
#   'tests',
#   'were',
#   'just',
#   'my',
#   'opinion',
#   'then',
#   'their',
#   'own',
#   'tests',
#   'which',
#   'would',
#   'then',
#   'be',
#   'their',
#   'opinion',
#   'would',
#   'contradict',
#   'mine',
#   'even',
#   'if',
#   'we',
#   'conducted',
#   'said',
#   'tests',
#   'in',
#   'identical',
#   'manner',
#   'no',
#   'they',
#   "don't",
#   'which',
#   'i',
#   'take',
#   'as',
#   'showing',
#   'these',
#   'tests',
#   'have',
#   'some',
#   'validity',
#   'beyond',
#   'our',
#   'opinion',
#   'of',
#   'them',
#   "i've",
#   'heard',
#   'of',
#   'no',
#   'way',
#   'to',
#   'verify',
#   'morality',
#   'in',
#   'a',
#   'consistent',
#   'way',
#   'much',
#   'less',
#   'compute',
#   'the',
#   'errors',
#   'of',
#   'the',
#   'measurement',
#   'care',
#   'to',
#   'enlighten',
#   'me',
#   'the',
#   'same',
#   'is',
#   'true',
#   'of',
#   'pain',
#   'but',
#   'painkillers',
#   'exist',
#   'and',
#   'can',
#   'be',
#   'predicted',
#   'to',
#   'work',
#   'with',
#   'some',
#   'accuracy',
#   'better',
#   'than',
#   'a',
#   'random',
#   'guess',
#   'map',
#   'the',
#   'activity',
#   'of',
#   'nerves',
#   'and',
#   'neural',
#   'activity',
#   'if',
#   'you',
#   'mean',
#   'physical',
#   'pain',
#   'you',
#   'have',
#   'a',
#   'sharp',
#   'point',
#   "i'll",
#   'give',
#   'you',
#   'that',
#   'but',
#   'you',
#   'still',
#   "haven't",
#   'given',
#   'me',
#   'a',
#   'way',
#   'to',
#   'quantify',
#   'morality',
#   'i',
#   'wrote',
#   'elsewhere',
#   'that',
#   'morality',
#   'should',
#   'be',
#   'hypotheses',
#   'about',
#   'observed',
#   'value',
#   'we',
#   'agree',
#   'hypotheses',
#   'however',
#   'can',
#   'change',
#   'i',
#   'hold',
#   'that',
#   'there',
#   'is',
#   'no',
#   'ultimate',
#   'hypothesis',
#   'of',
#   'morality',
#   'towards',
#   'which',
#   'these',
#   'changes',
#   'could',
#   'gravitate',
#   'but',
#   'that',
#   'they',
#   'could',
#   'be',
#   'changed',
#   'in',
#   'any',
#   'way',
#   'imaginable',
#   'producing',
#   'different',
#   'results',
#   'suitable',
#   'for',
#   'different',
#   'tasks',
#   'or',
#   'purposes',
#   'if',
#   'a',
#   'moral',
#   'system',
#   'makes',
#   'a',
#   'prediction',
#   'it',
#   'will',
#   'be',
#   'better',
#   'if',
#   'that',
#   'can',
#   'be',
#   'tested',
#   'better',
#   'and',
#   'worse',
#   'are',
#   'almost',
#   'always',
#   'defined',
#   'in',
#   'the',
#   'context',
#   'of',
#   'a',
#   'moral',
#   'system',
#   'your',
#   'prediction',
#   'will',
#   '_always_',
#   'be',
#   'correct',
#   'within',
#   'that',
#   'moral',
#   'system',
#   'what',
#   'you',
#   'need',
#   'now',
#   'is',
#   'an',
#   'objective',
#   'definition',
#   'of',
#   'good',
#   'and',
#   'bad',
#   'i',
#   'wish',
#   'you',
#   'luck',
#   "people's",
#   'ideas',
#   'about',
#   'the',
#   'age',
#   'of',
#   'object',
#   'x',
#   'are',
#   'not',
#   'objective',
#   'you',
#   'can',
#   'have',
#   'any',
#   'idea',
#   'you',
#   'like',
#   'and',
#   'i',
#   "can't",
#   'stop',
#   'you',
#   'universae',
#   'and',
#   'their',
#   'ages',
#   'is',
#   'another',
#   'ballgame',
#   'they',
#   'are',
#   'what',
#   'they',
#   'are',
#   'and',
#   'if',
#   'you',
#   'dislike',
#   'some',
#   'detail',
#   'of',
#   'them',
#   "that's",
#   'a',
#   'problem',
#   'with',
#   'your',
#   'opinion',
#   'of',
#   'them',
#   'sure',
#   'assume',
#   'an',
#   'objective',
#   'reality',
#   'and',
#   'you',
#   'get',
#   'statements',
#   'like',
#   'this',
#   "isn't",
#   'that',
#   'what',
#   "_you're_",
#   'doing',
#   'when',
#   'assuming',
#   'an',
#   'objectively',
#   'real',
#   'morality',
#   'besides',
#   'what',
#   '_exactly_',
#   'is',
#   'provably',
#   'wrong',
#   'with',
#   'my',
#   'statement',
#   'i',
#   'claim',
#   'that',
#   'morality',
#   'is',
#   'an',
#   'opinion',
#   'of',
#   'ours',
#   'and',
#   'as',
#   'such',
#   'subjective',
#   'and',
#   'individual',
#   'if',
#   "i'm",
#   'wrong',
#   'then',
#   'some',
#   'more',
#   'or',
#   'less',
#   'objectively',
#   'real',
#   'thing',
#   'exists',
#   'which',
#   'you',
#   'label',
#   'objective',
#   'morality',
#   'can',
#   'you',
#   'back',
#   'up',
#   'this',
#   'positive',
#   'claim',
#   'of',
#   'existence',
#   'can',
#   'you',
#   'back',
#   'up',
#   'your',
#   'positive',
#   'claim',
#   'above',
#   'no',
#   "that's",
#   'because',
#   "it's",
#   'an',
#   'assumption',
#   'i',
#   'make',
#   'the',
#   'same',
#   'assumption',
#   'about',
#   'values',
#   'on',
#   'the',
#   'basis',
#   'that',
#   'there',
#   'is',
#   'no',
#   'logical',
#   'difference',
#   'between',
#   'the',
#   'two',
#   'and',
#   'the',
#   'empirical',
#   'basis',
#   'of',
#   'the',
#   'two',
#   'is',
#   'precisely',
#   'the',
#   'same',
#   'claiming',
#   'there',
#   'is',
#   'no',
#   'objective',
#   'morality',
#   'is',
#   'suddenly',
#   'a',
#   'positive',
#   'claim',
#   'besides',
#   'i',
#   'think',
#   'i',
#   '_can_',
#   'lend',
#   'some',
#   'credence',
#   'to',
#   'my',
#   'claim',
#   'ponder',
#   'different',
#   'individuals',
#   'both',
#   'fully',
#   'functional',
#   'as',
#   'human',
#   'beings',
#   'and',
#   'members',
#   'of',
#   'society',
#   'but',
#   'yet',
#   'with',
#   'wildly',
#   'different',
#   'moral',
#   'codes',
#   'if',
#   'morality',
#   'was',
#   'objective',
#   'at',
#   'least',
#   'one',
#   'should',
#   'be',
#   'way',
#   'off',
#   'base',
#   'but',
#   'yet',
#   'hir',
#   "'incorrect'",
#   'morality',
#   'seems',
#   'to',
#   'function',
#   'fine',
#   'how',
#   'come',
#   'as',
#   'for',
#   'producing',
#   'these',
#   'individuals',
#   'it',
#   'might',
#   'be',
#   'easiest',
#   'to',
#   'pick',
#   'them',
#   'from',
#   'different',
#   'societies',
#   'say',
#   'an',
#   'islamic',
#   'one',
#   'and',
#   'some',
#   'polynesian',
#   'matrilineal',
#   'system',
#   'for',
#   'example',
#   'if',
#   'such',
#   'still',
#   'exist',
#   'deletia',
#   'testing',
#   'for',
#   'footballs',
#   'on',
#   'desks',
#   'now',
#   'take',
#   'a',
#   'look',
#   'at',
#   'morality',
#   'see',
#   'anything',
#   'if',
#   'so',
#   'please',
#   'inform',
#   'me',
#   'which',
#   'way',
#   'to',
#   'look',
#   'and',
#   'why',
#   'to',
#   'look',
#   'that',
#   'particular',
#   'way',
#   'as',
#   'opposed',
#   'to',
#   'some',
#   'other',
#   ...])

# %%
class Posting():
    def __init__(self, word, urls):
        self.word_ = word
        self.urls_ = urls

# %%
def index(tokenized_documents):
    postings = []
    tmp_postings = {}
    for doc in tokenized_documents:
        uniques = set(doc.words_)
        for word in uniques:
            if word in tmp_postings:
                tmp_postings[word] += [doc.url_]
            else:
                tmp_postings[word] = [doc.url_]
    for elm in tmp_postings.items():
        postings.append(Posting(elm[0], elm[1]))
    return postings

# %%
res = index(sample_tokenized_doc)
for e in res:
    print(e.word_, e.urls_)
# Out:
# mangoe ['./20news-bydate-test/alt.atheism/53420']
# why ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# isn't ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# some ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# stuff ['./20news-bydate-test/alt.atheism/53420']
# essentially ['./20news-bydate-test/alt.atheism/53420']
# text ['./20news-bydate-test/alt.atheism/53420']
# nt ['./20news-bydate-test/alt.atheism/53420']
# about ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# texts ['./20news-bydate-test/alt.atheism/53420']
# etc ['./20news-bydate-test/alt.atheism/53420']
# happened ['./20news-bydate-test/alt.atheism/53420']
# up ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# religion ['./20news-bydate-test/alt.atheism/53420']
# by ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# 1935 ['./20news-bydate-test/alt.atheism/53420']
# wingate ['./20news-bydate-test/alt.atheism/53420']
# world ['./20news-bydate-test/alt.atheism/53420']
# qumram ['./20news-bydate-test/alt.atheism/53420']
# differences ['./20news-bydate-test/alt.atheism/53420']
# though ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# readings ['./20news-bydate-test/alt.atheism/53420']
# particulars ['./20news-bydate-test/alt.atheism/53420']
# an ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# wpd ['./20news-bydate-test/alt.atheism/53420']
# greek ['./20news-bydate-test/alt.atheism/53420']
# story ['./20news-bydate-test/alt.atheism/53420']
# between ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# interpreted ['./20news-bydate-test/alt.atheism/53420']
# only ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# having ['./20news-bydate-test/alt.atheism/53420']
# abundance ['./20news-bydate-test/alt.atheism/53420']
# theological ['./20news-bydate-test/alt.atheism/53420']
# obviously ['./20news-bydate-test/alt.atheism/53420']
# and ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# back ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# know ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# we ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# analysis ['./20news-bydate-test/alt.atheism/53420']
# real ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# these ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# any ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# com ['./20news-bydate-test/alt.atheism/53420']
# textual ['./20news-bydate-test/alt.atheism/53420']
# umd ['./20news-bydate-test/alt.atheism/53420']
# on ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# reflect ['./20news-bydate-test/alt.atheism/53420']
# must ['./20news-bydate-test/alt.atheism/53420']
# latter ['./20news-bydate-test/alt.atheism/53420']
# scroll ['./20news-bydate-test/alt.atheism/53420']
# reference ['./20news-bydate-test/alt.atheism/53420']
# cs ['./20news-bydate-test/alt.atheism/53420']
# passages ['./20news-bydate-test/alt.atheism/53420']
# great ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# two ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# hebrew ['./20news-bydate-test/alt.atheism/53420']
# host ['./20news-bydate-test/alt.atheism/53420']
# no ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# is ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# corrupted ['./20news-bydate-test/alt.atheism/53420']
# time ['./20news-bydate-test/alt.atheism/53420']
# jon ['./20news-bydate-test/alt.atheism/53420']
# expert ['./20news-bydate-test/alt.atheism/53420']
# again ['./20news-bydate-test/alt.atheism/53420']
# because ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# standard ['./20news-bydate-test/alt.atheism/53420']
# septuagint ['./20news-bydate-test/alt.atheism/53420']
# import ['./20news-bydate-test/alt.atheism/53420']
# said ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# a ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# far ['./20news-bydate-test/alt.atheism/53420']
# completely ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# ancient ['./20news-bydate-test/alt.atheism/53420']
# for ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# translation ['./20news-bydate-test/alt.atheism/53420']
# addition ['./20news-bydate-test/alt.atheism/53420']
# reporters ['./20news-bydate-test/alt.atheism/53420']
# now ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# theologically ['./20news-bydate-test/alt.atheism/53420']
# point ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# have ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# expectation ['./20news-bydate-test/alt.atheism/53420']
# materials ['./20news-bydate-test/alt.atheism/53420']
# dss ['./20news-bydate-test/alt.atheism/53420']
# let's ['./20news-bydate-test/alt.atheism/53420']
# first ['./20news-bydate-test/alt.atheism/53420']
# not ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# apocrypha ['./20news-bydate-test/alt.atheism/53420']
# solntze ['./20news-bydate-test/alt.atheism/53420']
# bible ['./20news-bydate-test/alt.atheism/53420']
# additional ['./20news-bydate-test/alt.atheism/53420']
# do ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# papers ['./20news-bydate-test/alt.atheism/53420']
# there ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# translations ['./20news-bydate-test/alt.atheism/53420']
# aramaic ['./20news-bydate-test/alt.atheism/53420']
# which ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# variant ['./20news-bydate-test/alt.atheism/53420']
# 66615 ['./20news-bydate-test/alt.atheism/53420']
# at ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# has ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# but ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# corruptions ['./20news-bydate-test/alt.atheism/53420']
# people ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# big ['./20news-bydate-test/alt.atheism/53420']
# bigger ['./20news-bydate-test/alt.atheism/53420']
# surprises ['./20news-bydate-test/alt.atheism/53420']
# correctly ['./20news-bydate-test/alt.atheism/53420']
# also ['./20news-bydate-test/alt.atheism/53420']
# this ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# edu ['./20news-bydate-test/alt.atheism/53420']
# knowledge ['./20news-bydate-test/alt.atheism/53420']
# masoretic ['./20news-bydate-test/alt.atheism/53420']
# best ['./20news-bydate-test/alt.atheism/53420']
# be ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# reading ['./20news-bydate-test/alt.atheism/53420']
# different ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# includes ['./20news-bydate-test/alt.atheism/53420']
# misunderstand ['./20news-bydate-test/alt.atheism/53420']
# they ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# obvious ['./20news-bydate-test/alt.atheism/53420']
# scholars ['./20news-bydate-test/alt.atheism/53420']
# sea ['./20news-bydate-test/alt.atheism/53420']
# it ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# material ['./20news-bydate-test/alt.atheism/53420']
# newspapers ['./20news-bydate-test/alt.atheism/53420']
# sign ['./20news-bydate-test/alt.atheism/53420']
# re ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# thus ['./20news-bydate-test/alt.atheism/53420']
# commentaries ['./20news-bydate-test/alt.atheism/53420']
# lurking ['./20news-bydate-test/alt.atheism/53420']
# proceeded ['./20news-bydate-test/alt.atheism/53420']
# as ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# were ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# tend ['./20news-bydate-test/alt.atheism/53420']
# to ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# issues ['./20news-bydate-test/alt.atheism/53420']
# emphasized ['./20news-bydate-test/alt.atheism/53420']
# various ['./20news-bydate-test/alt.atheism/53420']
# when ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# did ['./20news-bydate-test/alt.atheism/53420']
# you're ['./20news-bydate-test/alt.atheism/53420']
# too ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# present ['./20news-bydate-test/alt.atheism/53420']
# significant ['./20news-bydate-test/alt.atheism/53420']
# ot ['./20news-bydate-test/alt.atheism/53420']
# nntp ['./20news-bydate-test/alt.atheism/53420']
# the ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# lines ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# what ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# dead ['./20news-bydate-test/alt.atheism/53420']
# predating ['./20news-bydate-test/alt.atheism/53420']
# jewish ['./20news-bydate-test/alt.atheism/53420']
# was ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# where ['./20news-bydate-test/alt.atheism/53420']
# sgi ['./20news-bydate-test/alt.atheism/53420']
# prone ['./20news-bydate-test/alt.atheism/53420']
# satanic ['./20news-bydate-test/alt.atheism/53420']
# had ['./20news-bydate-test/alt.atheism/53420']
# vary ['./20news-bydate-test/alt.atheism/53420']
# other ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# subject ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# signifcant ['./20news-bydate-test/alt.atheism/53420']
# all ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# learn ['./20news-bydate-test/alt.atheism/53420']
# writes ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# extra ['./20news-bydate-test/alt.atheism/53420']
# posting ['./20news-bydate-test/alt.atheism/53420']
# mimsy ['./20news-bydate-test/alt.atheism/53420']
# i ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# organization ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# newspaper ['./20news-bydate-test/alt.atheism/53420']
# fragments ['./20news-bydate-test/alt.atheism/53420']
# sizes ['./20news-bydate-test/alt.atheism/53420']
# 56 ['./20news-bydate-test/alt.atheism/53420']
# variations ['./20news-bydate-test/alt.atheism/53420']
# books ['./20news-bydate-test/alt.atheism/53420']
# headline ['./20news-bydate-test/alt.atheism/53420']
# are ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# does ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# my ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# add ['./20news-bydate-test/alt.atheism/53420']
# isaiah ['./20news-bydate-test/alt.atheism/53420']
# from ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# error ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# of ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# notoriously ['./20news-bydate-test/alt.atheism/53420']
# tradition ['./20news-bydate-test/alt.atheism/53420']
# important ['./20news-bydate-test/alt.atheism/53420']
# distribution ['./20news-bydate-test/alt.atheism/53420']
# article ['./20news-bydate-test/alt.atheism/53420']
# so ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# took ['./20news-bydate-test/alt.atheism/53420']
# interests ['./20news-bydate-test/alt.atheism/53420']
# past ['./20news-bydate-test/alt.atheism/53420']
# ignorant ['./20news-bydate-test/alt.atheism/53420']
# kind ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# charley ['./20news-bydate-test/alt.atheism/53420']
# exclude ['./20news-bydate-test/alt.atheism/53420']
# almost ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# livesey ['./20news-bydate-test/alt.atheism/53420']
# differs ['./20news-bydate-test/alt.atheism/53420']
# little ['./20news-bydate-test/alt.atheism/53420']
# places ['./20news-bydate-test/alt.atheism/53420']
# idea ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# in ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# read ['./20news-bydate-test/alt.atheism/53420']
# second ['./20news-bydate-test/alt.atheism/53420']
# versions ['./20news-bydate-test/alt.atheism/53420']
# antecdent ['./20news-bydate-test/alt.atheism/53420']
# hey ['./20news-bydate-test/alt.atheism/53420']
# exaggeration ['./20news-bydate-test/alt.atheism/53420']
# unlike ['./20news-bydate-test/alt.atheism/53420']
# hasn't ['./20news-bydate-test/alt.atheism/53420']
# targums ['./20news-bydate-test/alt.atheism/53420']
# copied ['./20news-bydate-test/alt.atheism/53420']
# faithfully ['./20news-bydate-test/alt.atheism/53420']
# copy ['./20news-bydate-test/alt.atheism/53420']
# fixing ['./20news-bydate-test/alt.atheism/53420']
# that ['./20news-bydate-test/alt.atheism/53420', './20news-bydate-test/alt.atheism/53639']
# really ['./20news-bydate-test/alt.atheism/53639']
# activity ['./20news-bydate-test/alt.atheism/53639']
# andtbacka ['./20news-bydate-test/alt.atheism/53639']
# exists ['./20news-bydate-test/alt.atheism/53639']
# deletia ['./20news-bydate-test/alt.atheism/53639']
# provably ['./20news-bydate-test/alt.atheism/53639']
# single ['./20news-bydate-test/alt.atheism/53639']
# object ['./20news-bydate-test/alt.atheism/53639']
# less ['./20news-bydate-test/alt.atheism/53639']
# _exactly_ ['./20news-bydate-test/alt.atheism/53639']
# inform ['./20news-bydate-test/alt.atheism/53639']
# function ['./20news-bydate-test/alt.atheism/53639']
# look ['./20news-bydate-test/alt.atheism/53639']
# tried ['./20news-bydate-test/alt.atheism/53639']
# doesn't ['./20news-bydate-test/alt.atheism/53639']
# how ['./20news-bydate-test/alt.atheism/53639']
# manner ['./20news-bydate-test/alt.atheism/53639']
# 21 ['./20news-bydate-test/alt.atheism/53639']
# never ['./20news-bydate-test/alt.atheism/53639']
# assert ['./20news-bydate-test/alt.atheism/53639']
# say ['./20news-bydate-test/alt.atheism/53639']
# functional ['./20news-bydate-test/alt.atheism/53639']
# vms ['./20news-bydate-test/alt.atheism/53639']
# case ['./20news-bydate-test/alt.atheism/53639']
# come ['./20news-bydate-test/alt.atheism/53639']
# speaker ['./20news-bydate-test/alt.atheism/53639']
# given ['./20news-bydate-test/alt.atheism/53639']
# validity ['./20news-bydate-test/alt.atheism/53639']
# hypotheses ['./20news-bydate-test/alt.atheism/53639']
# biblical ['./20news-bydate-test/alt.atheism/53639']
# gmt ['./20news-bydate-test/alt.atheism/53639']
# statements ['./20news-bydate-test/alt.atheism/53639']
# off ['./20news-bydate-test/alt.atheism/53639']
# errors ['./20news-bydate-test/alt.atheism/53639']
# task ['./20news-bydate-test/alt.atheism/53639']
# your ['./20news-bydate-test/alt.atheism/53639']
# into ['./20news-bydate-test/alt.atheism/53639']
# word ['./20news-bydate-test/alt.atheism/53639']
# uucp's ['./20news-bydate-test/alt.atheism/53639']
# bars ['./20news-bydate-test/alt.atheism/53639']
# ours ['./20news-bydate-test/alt.atheism/53639']
# results ['./20news-bydate-test/alt.atheism/53639']
# think ['./20news-bydate-test/alt.atheism/53639']
# effect ['./20news-bydate-test/alt.atheism/53639']
# haven't ['./20news-bydate-test/alt.atheism/53639']
# objectively ['./20news-bydate-test/alt.atheism/53639']
# base ['./20news-bydate-test/alt.atheism/53639']
# 09 ['./20news-bydate-test/alt.atheism/53639']
# 1993 ['./20news-bydate-test/alt.atheism/53639']
# evidence ['./20news-bydate-test/alt.atheism/53639']
# sharp ['./20news-bydate-test/alt.atheism/53639']
# abo ['./20news-bydate-test/alt.atheism/53639']
# easiest ['./20news-bydate-test/alt.atheism/53639']
# conducted ['./20news-bydate-test/alt.atheism/53639']
# hard ['./20news-bydate-test/alt.atheism/53639']
# yes ['./20news-bydate-test/alt.atheism/53639']
# consistent ['./20news-bydate-test/alt.atheism/53639']
# opinions ['./20news-bydate-test/alt.atheism/53639']
# with ['./20news-bydate-test/alt.atheism/53639']
# nerves ['./20news-bydate-test/alt.atheism/53639']
# extreme ['./20news-bydate-test/alt.atheism/53639']
# measuring ['./20news-bydate-test/alt.atheism/53639']
# uucp ['./20news-bydate-test/alt.atheism/53639']
# them ['./20news-bydate-test/alt.atheism/53639']
# seems ['./20news-bydate-test/alt.atheism/53639']
# usage ['./20news-bydate-test/alt.atheism/53639']
# example ['./20news-bydate-test/alt.atheism/53639']
# english ['./20news-bydate-test/alt.atheism/53639']
# refute ['./20news-bydate-test/alt.atheism/53639']
# might ['./20news-bydate-test/alt.atheism/53639']
# precisely ['./20news-bydate-test/alt.atheism/53639']
# predicted ['./20news-bydate-test/alt.atheism/53639']
# consistently ['./20news-bydate-test/alt.atheism/53639']
# result ['./20news-bydate-test/alt.atheism/53639']
# anything ['./20news-bydate-test/alt.atheism/53639']
# record ['./20news-bydate-test/alt.atheism/53639']
# achieve ['./20news-bydate-test/alt.atheism/53639']
# even ['./20news-bydate-test/alt.atheism/53639']
# suitable ['./20news-bydate-test/alt.atheism/53639']
# simple ['./20news-bydate-test/alt.atheism/53639']
# mats ['./20news-bydate-test/alt.atheism/53639']
# things ['./20news-bydate-test/alt.atheism/53639']
# may ['./20news-bydate-test/alt.atheism/53639']
# within ['./20news-bydate-test/alt.atheism/53639']
# fine ['./20news-bydate-test/alt.atheism/53639']
# mandtbacka ['./20news-bydate-test/alt.atheism/53639']
# 2000 ['./20news-bydate-test/alt.atheism/53639']
# belief ['./20news-bydate-test/alt.atheism/53639']
# should ['./20news-bydate-test/alt.atheism/53639']
# map ['./20news-bydate-test/alt.atheism/53639']
# imaginable ['./20news-bydate-test/alt.atheism/53639']
# both ['./20news-bydate-test/alt.atheism/53639']
# universae ['./20news-bydate-test/alt.atheism/53639']
# dislike ['./20news-bydate-test/alt.atheism/53639']
# d012s658 ['./20news-bydate-test/alt.atheism/53639']
# you ['./20news-bydate-test/alt.atheism/53639']
# random ['./20news-bydate-test/alt.atheism/53639']
# claiming ['./20news-bydate-test/alt.atheism/53639']
# 151 ['./20news-bydate-test/alt.atheism/53639']
# problem ['./20news-bydate-test/alt.atheism/53639']
# prediction ['./20news-bydate-test/alt.atheism/53639']
# individual ['./20news-bydate-test/alt.atheism/53639']
# immutable ['./20news-bydate-test/alt.atheism/53639']
# ballgame ['./20news-bydate-test/alt.atheism/53639']
# fi ['./20news-bydate-test/alt.atheism/53639']
# amount ['./20news-bydate-test/alt.atheism/53639']
# contradict ['./20news-bydate-test/alt.atheism/53639']
# sure ['./20news-bydate-test/alt.atheism/53639']
# implications ['./20news-bydate-test/alt.atheism/53639']
# s ['./20news-bydate-test/alt.atheism/53639']
# blatant ['./20news-bydate-test/alt.atheism/53639']
# changed ['./20news-bydate-test/alt.atheism/53639']
# goal ['./20news-bydate-test/alt.atheism/53639']
# such ['./20news-bydate-test/alt.atheism/53639']
# scientific ['./20news-bydate-test/alt.atheism/53639']
# murder ['./20news-bydate-test/alt.atheism/53639']
# i'll ['./20news-bydate-test/alt.atheism/53639']
# clearly ['./20news-bydate-test/alt.atheism/53639']
# seemingly ['./20news-bydate-test/alt.atheism/53639']
# empirical ['./20news-bydate-test/alt.atheism/53639']
# calculations ['./20news-bydate-test/alt.atheism/53639']
# creationist ['./20news-bydate-test/alt.atheism/53639']
# islamic ['./20news-bydate-test/alt.atheism/53639']
# wrong ['./20news-bydate-test/alt.atheism/53639']
# need ['./20news-bydate-test/alt.atheism/53639']
# me ['./20news-bydate-test/alt.atheism/53639']
# wrote ['./20news-bydate-test/alt.atheism/53639']
# something ['./20news-bydate-test/alt.atheism/53639']
# depend ['./20news-bydate-test/alt.atheism/53639']
# saying ['./20news-bydate-test/alt.atheism/53639']
# being ['./20news-bydate-test/alt.atheism/53639']
# track ['./20news-bydate-test/alt.atheism/53639']
# seldom ['./20news-bydate-test/alt.atheism/53639']
# christian ['./20news-bydate-test/alt.atheism/53639']
# humanity's ['./20news-bydate-test/alt.atheism/53639']
# assumes ['./20news-bydate-test/alt.atheism/53639']
# painkillers ['./20news-bydate-test/alt.atheism/53639']
# _you're_ ['./20news-bydate-test/alt.atheism/53639']
# will ['./20news-bydate-test/alt.atheism/53639']
# finabo ['./20news-bydate-test/alt.atheism/53639']
# rat's ['./20news-bydate-test/alt.atheism/53639']
# logically ['./20news-bydate-test/alt.atheism/53639']
# opinion ['./20news-bydate-test/alt.atheism/53639']
# another ['./20news-bydate-test/alt.atheism/53639']
# cosmology ['./20news-bydate-test/alt.atheism/53639']
# sort ['./20news-bydate-test/alt.atheism/53639']
# that'll ['./20news-bydate-test/alt.atheism/53639']
# thing ['./20news-bydate-test/alt.atheism/53639']
# more ['./20news-bydate-test/alt.atheism/53639']
# mean ['./20news-bydate-test/alt.atheism/53639']
# still ['./20news-bydate-test/alt.atheism/53639']
# stone ['./20news-bydate-test/alt.atheism/53639']
# care ['./20news-bydate-test/alt.atheism/53639']
# imagine ['./20news-bydate-test/alt.atheism/53639']
# circumstances ['./20news-bydate-test/alt.atheism/53639']
# measurement ['./20news-bydate-test/alt.atheism/53639']
# frank ['./20news-bydate-test/alt.atheism/53639']
# always ['./20news-bydate-test/alt.atheism/53639']
# times ['./20news-bydate-test/alt.atheism/53639']
# unorganized ['./20news-bydate-test/alt.atheism/53639']
# indeed ['./20news-bydate-test/alt.atheism/53639']
# verified ['./20news-bydate-test/alt.atheism/53639']
# ideas ['./20news-bydate-test/alt.atheism/53639']
# question ['./20news-bydate-test/alt.atheism/53639']
# misunderstood ['./20news-bydate-test/alt.atheism/53639']
# verify ['./20news-bydate-test/alt.atheism/53639']
# members ['./20news-bydate-test/alt.atheism/53639']
# semantics ['./20news-bydate-test/alt.atheism/53639']
# native ['./20news-bydate-test/alt.atheism/53639']
# basis ['./20news-bydate-test/alt.atheism/53639']
# assumption ['./20news-bydate-test/alt.atheism/53639']
# ultimate ['./20news-bydate-test/alt.atheism/53639']
# mass ['./20news-bydate-test/alt.atheism/53639']
# their ['./20news-bydate-test/alt.atheism/53639']
# then ['./20news-bydate-test/alt.atheism/53639']
# above ['./20news-bydate-test/alt.atheism/53639']
# would ['./20news-bydate-test/alt.atheism/53639']
# logical ['./20news-bydate-test/alt.atheism/53639']
# under ['./20news-bydate-test/alt.atheism/53639']
# mchp ['./20news-bydate-test/alt.atheism/53639']
# guess ['./20news-bydate-test/alt.atheism/53639']
# albeit ['./20news-bydate-test/alt.atheism/53639']
# we'd ['./20news-bydate-test/alt.atheism/53639']
# apr ['./20news-bydate-test/alt.atheism/53639']
# method ['./20news-bydate-test/alt.atheism/53639']
# work ['./20news-bydate-test/alt.atheism/53639']
# those ['./20news-bydate-test/alt.atheism/53639']
# same ['./20news-bydate-test/alt.atheism/53639']
# put ['./20news-bydate-test/alt.atheism/53639']
# news ['./20news-bydate-test/alt.atheism/53639']
# get ['./20news-bydate-test/alt.atheism/53639']
# secondly ['./20news-bydate-test/alt.atheism/53639']
# pain ['./20news-bydate-test/alt.atheism/53639']
# don't ['./20news-bydate-test/alt.atheism/53639']
# cases ['./20news-bydate-test/alt.atheism/53639']
# debating ['./20news-bydate-test/alt.atheism/53639']
# please ['./20news-bydate-test/alt.atheism/53639']
# existence ['./20news-bydate-test/alt.atheism/53639']
# wiped ['./20news-bydate-test/alt.atheism/53639']
# gravitate ['./20news-bydate-test/alt.atheism/53639']
# uninc ['./20news-bydate-test/alt.atheism/53639']
# difference ['./20news-bydate-test/alt.atheism/53639']
# own ['./20news-bydate-test/alt.atheism/53639']
# non ['./20news-bydate-test/alt.atheism/53639']
# quibble ['./20news-bydate-test/alt.atheism/53639']
# true ['./20news-bydate-test/alt.atheism/53639']
# 24 ['./20news-bydate-test/alt.atheism/53639']
# agree ['./20news-bydate-test/alt.atheism/53639']
# identical ['./20news-bydate-test/alt.atheism/53639']
# horus ['./20news-bydate-test/alt.atheism/53639']
# begging ['./20news-bydate-test/alt.atheism/53639']
# ages ['./20news-bydate-test/alt.atheism/53639']
# de ['./20news-bydate-test/alt.atheism/53639']
# sticking ['./20news-bydate-test/alt.atheism/53639']
# amazed ['./20news-bydate-test/alt.atheism/53639']
# enlighten ['./20news-bydate-test/alt.atheism/53639']
# proving ['./20news-bydate-test/alt.atheism/53639']
# 38 ['./20news-bydate-test/alt.atheism/53639']
# i'm ['./20news-bydate-test/alt.atheism/53639']
# facts ['./20news-bydate-test/alt.atheism/53639']
# stop ['./20news-bydate-test/alt.atheism/53639']
# internally ['./20news-bydate-test/alt.atheism/53639']
# noticed ['./20news-bydate-test/alt.atheism/53639']
# through ['./20news-bydate-test/alt.atheism/53639']
# independent ['./20news-bydate-test/alt.atheism/53639']
# most ['./20news-bydate-test/alt.atheism/53639']
# tasks ['./20news-bydate-test/alt.atheism/53639']
# than ['./20news-bydate-test/alt.atheism/53639']
# i'd ['./20news-bydate-test/alt.atheism/53639']
# 43 ['./20news-bydate-test/alt.atheism/53639']
# matrilineal ['./20news-bydate-test/alt.atheism/53639']
# society ['./20news-bydate-test/alt.atheism/53639']
# oxymoron ['./20news-bydate-test/alt.atheism/53639']
# codes ['./20news-bydate-test/alt.atheism/53639']
# values ['./20news-bydate-test/alt.atheism/53639']
# sni ['./20news-bydate-test/alt.atheism/53639']
# way ['./20news-bydate-test/alt.atheism/53639']
# hfj ['./20news-bydate-test/alt.atheism/53639']
# ap ['./20news-bydate-test/alt.atheism/53639']
# self ['./20news-bydate-test/alt.atheism/53639']
# polynesian ['./20news-bydate-test/alt.atheism/53639']
# out ['./20news-bydate-test/alt.atheism/53639']
# lend ['./20news-bydate-test/alt.atheism/53639']
# like ['./20news-bydate-test/alt.atheism/53639']
# individuals ['./20news-bydate-test/alt.atheism/53639']
# usenet ['./20news-bydate-test/alt.atheism/53639']
# give ['./20news-bydate-test/alt.atheism/53639']
# take ['./20news-bydate-test/alt.atheism/53639']
# power ['./20news-bydate-test/alt.atheism/53639']
# pick ['./20news-bydate-test/alt.atheism/53639']
# neural ['./20news-bydate-test/alt.atheism/53639']
# astronomy ['./20news-bydate-test/alt.atheism/53639']
# changes ['./20news-bydate-test/alt.atheism/53639']
# claim ['./20news-bydate-test/alt.atheism/53639']
# areas ['./20news-bydate-test/alt.atheism/53639']
# tested ['./20news-bydate-test/alt.atheism/53639']
# many ['./20news-bydate-test/alt.atheism/53639']
# lot ['./20news-bydate-test/alt.atheism/53639']
# mine ['./20news-bydate-test/alt.atheism/53639']
# until ['./20news-bydate-test/alt.atheism/53639']
# compute ['./20news-bydate-test/alt.atheism/53639']
# heard ['./20news-bydate-test/alt.atheism/53639']
# ponder ['./20news-bydate-test/alt.atheism/53639']
# perfectly ['./20news-bydate-test/alt.atheism/53639']
# correct ['./20news-bydate-test/alt.atheism/53639']
# subjective ['./20news-bydate-test/alt.atheism/53639']
# line ['./20news-bydate-test/alt.atheism/53639']
# physical ['./20news-bydate-test/alt.atheism/53639']
# down ['./20news-bydate-test/alt.atheism/53639']
# reason ['./20news-bydate-test/alt.atheism/53639']
# applied ['./20news-bydate-test/alt.atheism/53639']
# definition ['./20news-bydate-test/alt.atheism/53639']
# morality ['./20news-bydate-test/alt.atheism/53639']
# side ['./20news-bydate-test/alt.atheism/53639']
# drift ['./20news-bydate-test/alt.atheism/53639']
# 1r34n3 ['./20news-bydate-test/alt.atheism/53639']
# sometimes ['./20news-bydate-test/alt.atheism/53639']
# speak ['./20news-bydate-test/alt.atheism/53639']
# performs ['./20news-bydate-test/alt.atheism/53639']
# much ['./20news-bydate-test/alt.atheism/53639']
# longer ['./20news-bydate-test/alt.atheism/53639']
# however ['./20news-bydate-test/alt.atheism/53639']
# _always_ ['./20news-bydate-test/alt.atheism/53639']
# systems ['./20news-bydate-test/alt.atheism/53639']
# elsewhere ['./20news-bydate-test/alt.atheism/53639']
# towards ['./20news-bydate-test/alt.atheism/53639']
# assuming ['./20news-bydate-test/alt.atheism/53639']
# credence ['./20news-bydate-test/alt.atheism/53639']
# suddenly ['./20news-bydate-test/alt.atheism/53639']
# thereby ['./20news-bydate-test/alt.atheism/53639']
# least ['./20news-bydate-test/alt.atheism/53639']
# direct ['./20news-bydate-test/alt.atheism/53639']
# message ['./20news-bydate-test/alt.atheism/53639']
# age ['./20news-bydate-test/alt.atheism/53639']
# can't ['./20news-bydate-test/alt.atheism/53639']
# showing ['./20news-bydate-test/alt.atheism/53639']
# make ['./20news-bydate-test/alt.atheism/53639']
# x ['./20news-bydate-test/alt.atheism/53639']
# beyond ['./20news-bydate-test/alt.atheism/53639']
# statement ['./20news-bydate-test/alt.atheism/53639']
# purposes ['./20news-bydate-test/alt.atheism/53639']
# fixed ['./20news-bydate-test/alt.atheism/53639']
# testing ['./20news-bydate-test/alt.atheism/53639']
# reader ['./20news-bydate-test/alt.atheism/53639']
# largish ['./20news-bydate-test/alt.atheism/53639']
# roughly ['./20news-bydate-test/alt.atheism/53639']
# better ['./20news-bydate-test/alt.atheism/53639']
# opposed ['./20news-bydate-test/alt.atheism/53639']
# makes ['./20news-bydate-test/alt.atheism/53639']
# emirically ['./20news-bydate-test/alt.atheism/53639']
# anybody ['./20news-bydate-test/alt.atheism/53639']
# if ['./20news-bydate-test/alt.atheism/53639']
# universe ['./20news-bydate-test/alt.atheism/53639']
# insane ['./20news-bydate-test/alt.atheism/53639']
# value ['./20news-bydate-test/alt.atheism/53639']
# reality ['./20news-bydate-test/alt.atheism/53639']
# see ['./20news-bydate-test/alt.atheism/53639']
# conclude ['./20news-bydate-test/alt.atheism/53639']
# societies ['./20news-bydate-test/alt.atheism/53639']
# spaniards ['./20news-bydate-test/alt.atheism/53639']
# luck ['./20news-bydate-test/alt.atheism/53639']
# together ['./20news-bydate-test/alt.atheism/53639']
# loss ['./20news-bydate-test/alt.atheism/53639']
# detail ['./20news-bydate-test/alt.atheism/53639']
# young ['./20news-bydate-test/alt.atheism/53639']
# can ['./20news-bydate-test/alt.atheism/53639']
# moral ['./20news-bydate-test/alt.atheism/53639']
# tests ['./20news-bydate-test/alt.atheism/53639']
# wish ['./20news-bydate-test/alt.atheism/53639']
# stick ['./20news-bydate-test/alt.atheism/53639']
# besides ['./20news-bydate-test/alt.atheism/53639']
# who ['./20news-bydate-test/alt.atheism/53639']
# apologies ['./20news-bydate-test/alt.atheism/53639']
# he ['./20news-bydate-test/alt.atheism/53639']
# context ['./20news-bydate-test/alt.atheism/53639']
# hypothesis ['./20news-bydate-test/alt.atheism/53639']
# yet ['./20news-bydate-test/alt.atheism/53639']
# defined ['./20news-bydate-test/alt.atheism/53639']
# calculating ['./20news-bydate-test/alt.atheism/53639']
# or ['./20news-bydate-test/alt.atheism/53639']
# else ['./20news-bydate-test/alt.atheism/53639']
# that's ['./20news-bydate-test/alt.atheism/53639']
# objective ['./20news-bydate-test/alt.atheism/53639']
# bad ['./20news-bydate-test/alt.atheism/53639']
# human ['./20news-bydate-test/alt.atheism/53639']
# 'incorrect' ['./20news-bydate-test/alt.atheism/53639']
# hadn't ['./20news-bydate-test/alt.atheism/53639']
# beings ['./20news-bydate-test/alt.atheism/53639']
# footballs ['./20news-bydate-test/alt.atheism/53639']
# seem ['./20news-bydate-test/alt.atheism/53639']
# people's ['./20news-bydate-test/alt.atheism/53639']
# quite ['./20news-bydate-test/alt.atheism/53639']
# reply ['./20news-bydate-test/alt.atheism/53639']
# _real_ ['./20news-bydate-test/alt.atheism/53639']
# debate ['./20news-bydate-test/alt.atheism/53639']
# one ['./20news-bydate-test/alt.atheism/53639']
# ass ['./20news-bydate-test/alt.atheism/53639']
# after ['./20news-bydate-test/alt.atheism/53639']
# our ['./20news-bydate-test/alt.atheism/53639']
# performing ['./20news-bydate-test/alt.atheism/53639']
# system ['./20news-bydate-test/alt.atheism/53639']
# beliefs ['./20news-bydate-test/alt.atheism/53639']
# means ['./20news-bydate-test/alt.atheism/53639']
# fully ['./20news-bydate-test/alt.atheism/53639']
# hir ['./20news-bydate-test/alt.atheism/53639']
# doing ['./20news-bydate-test/alt.atheism/53639']
# matter ['./20news-bydate-test/alt.atheism/53639']
# change ['./20news-bydate-test/alt.atheism/53639']
# hitting ['./20news-bydate-test/alt.atheism/53639']
# lead ['./20news-bydate-test/alt.atheism/53639']
# 1 ['./20news-bydate-test/alt.atheism/53639']
# useless ['./20news-bydate-test/alt.atheism/53639']
# just ['./20news-bydate-test/alt.atheism/53639']
# its ['./20news-bydate-test/alt.atheism/53639']
# exist ['./20news-bydate-test/alt.atheism/53639']
# quantify ['./20news-bydate-test/alt.atheism/53639']
# disclaimer ['./20news-bydate-test/alt.atheism/53639']
# aztecs ['./20news-bydate-test/alt.atheism/53639']
# good ['./20news-bydate-test/alt.atheism/53639']
# particular ['./20news-bydate-test/alt.atheism/53639']
# _can_ ['./20news-bydate-test/alt.atheism/53639']
# wildly ['./20news-bydate-test/alt.atheism/53639']
# could ['./20news-bydate-test/alt.atheism/53639']
# postings ['./20news-bydate-test/alt.atheism/53639']
# observed ['./20news-bydate-test/alt.atheism/53639']
# ever ['./20news-bydate-test/alt.atheism/53639']
# assume ['./20news-bydate-test/alt.atheism/53639']
# producing ['./20news-bydate-test/alt.atheism/53639']
# humanity ['./20news-bydate-test/alt.atheism/53639']
# it's ['./20news-bydate-test/alt.atheism/53639']
# test ['./20news-bydate-test/alt.atheism/53639']
# desks ['./20news-bydate-test/alt.atheism/53639']
# accuracy ['./20news-bydate-test/alt.atheism/53639']
# label ['./20news-bydate-test/alt.atheism/53639']
# i've ['./20news-bydate-test/alt.atheism/53639']
# hold ['./20news-bydate-test/alt.atheism/53639']
# positive ['./20news-bydate-test/alt.atheism/53639']
# worse ['./20news-bydate-test/alt.atheism/53639']
# years ['./20news-bydate-test/alt.atheism/53639']
# thought ['./20news-bydate-test/alt.atheism/53639']

# %%
class Index():
    def __init__(self, urlToDid, wordToDids, DidToUrl):
        self.urlToDid_ = urlToDid
        self.wordToDids_ = wordToDids
        self.DidToUrl_ = DidToUrl
        # Je ne vois pas comment faire search() de manière
        # pas trop moche sans °_°

# %%
def build(postings):
    urlToDid = {}
    wordToDid = {}
    
    DidToUrl = {}
    
    # building urlToDid
    accId = 0
    for po in postings:
        for url in po.urls_:
            if url not in urlToDid:
                urlToDid[url] = accId
                
                DidToUrl[accId] = url
                
                accId += 1
    
    # building wordToDid
    for po in postings:
        wordToDid[po.word_] = []
        for url in po.urls_:
            wordToDid[po.word_].append(urlToDid[url])
    
    return Index(urlToDid, wordToDid, DidToUrl)

# %%
import pickle

def save(index, path):
    file = open(path, 'wb')
    pickle.dump(index, file)
    file.close()

def load(path):
    file = open(path, 'rb')
    index = pickle.load(file)
    file.close()
    return index

# %% [markdown]
# # TOPO
#
# > **TODO** : Soigner la selection de fichier

# %%
myindex = build(res)
save(myindex, "savedIndex")

# %%
myindex.urlToDid_
# Out:
# {'./20news-bydate-test/alt.atheism/53420': 0,
#  './20news-bydate-test/alt.atheism/53639': 1}

# %%
class MySearcher():
    def __init__(self, paths):
        self.indexs_ = [load(path) for path in paths]
    
    def search(self, word):
        res = []
        for index in self.indexs_:
            if word in index.wordToDids_:
                res += [index.DidToUrl_[did] for did in index.wordToDids_[word]]
        return res
    
    def searchOneOf(self, words):
        uniques = set()
        for word in words:
            tmp_result = self.search(word)
            for elm in tmp_result:
                uniques.add(elm)
        return list(uniques)
    
    def searchAllOf(self, words):
        uniques = set(self.search(words[0]))
        for word in words[1:]:
            tmp_result = set(self.search(word))
            for elm in tmp_result:
                uniques.intersection(elm)
        return list(uniques)

# %%
mySearcher = MySearcher(['savedIndex'])
mySearcher.search('in')
# Out:
# ['./20news-bydate-test/alt.atheism/53420',
#  './20news-bydate-test/alt.atheism/53639']

# %%
myindex.wordToDids_
# Out:
# {'mangoe': [0],
#  'why': [0, 1],
#  "isn't": [0, 1],
#  'some': [0, 1],
#  'stuff': [0],
#  'essentially': [0],
#  'text': [0],
#  'nt': [0],
#  'about': [0, 1],
#  'texts': [0],
#  'etc': [0],
#  'happened': [0],
#  'up': [0, 1],
#  'religion': [0],
#  'by': [0, 1],
#  '1935': [0],
#  'wingate': [0],
#  'world': [0],
#  'qumram': [0],
#  'differences': [0],
#  'though': [0, 1],
#  'readings': [0],
#  'particulars': [0],
#  'an': [0, 1],
#  'wpd': [0],
#  'greek': [0],
#  'story': [0],
#  'between': [0, 1],
#  'interpreted': [0],
#  'only': [0, 1],
#  'having': [0],
#  'abundance': [0],
#  'theological': [0],
#  'obviously': [0],
#  'and': [0, 1],
#  'back': [0, 1],
#  'know': [0, 1],
#  'we': [0, 1],
#  'analysis': [0],
#  'real': [0, 1],
#  'these': [0, 1],
#  'any': [0, 1],
#  'com': [0],
#  'textual': [0],
#  'umd': [0],
#  'on': [0, 1],
#  'reflect': [0],
#  'must': [0],
#  'latter': [0],
#  'scroll': [0],
#  'reference': [0],
#  'cs': [0],
#  'passages': [0],
#  'great': [0, 1],
#  'two': [0, 1],
#  'hebrew': [0],
#  'host': [0],
#  'no': [0, 1],
#  'is': [0, 1],
#  'corrupted': [0],
#  'time': [0],
#  'jon': [0],
#  'expert': [0],
#  'again': [0],
#  'because': [0, 1],
#  'standard': [0],
#  'septuagint': [0],
#  'import': [0],
#  'said': [0, 1],
#  'a': [0, 1],
#  'far': [0],
#  'completely': [0, 1],
#  'ancient': [0],
#  'for': [0, 1],
#  'translation': [0],
#  'addition': [0],
#  'reporters': [0],
#  'now': [0, 1],
#  'theologically': [0],
#  'point': [0, 1],
#  'have': [0, 1],
#  'expectation': [0],
#  'materials': [0],
#  'dss': [0],
#  "let's": [0],
#  'first': [0],
#  'not': [0, 1],
#  'apocrypha': [0],
#  'solntze': [0],
#  'bible': [0],
#  'additional': [0],
#  'do': [0, 1],
#  'papers': [0],
#  'there': [0, 1],
#  'translations': [0],
#  'aramaic': [0],
#  'which': [0, 1],
#  'variant': [0],
#  '66615': [0],
#  'at': [0, 1],
#  'has': [0, 1],
#  'but': [0, 1],
#  'corruptions': [0],
#  'people': [0, 1],
#  'big': [0],
#  'bigger': [0],
#  'surprises': [0],
#  'correctly': [0],
#  'also': [0],
#  'this': [0, 1],
#  'edu': [0],
#  'knowledge': [0],
#  'masoretic': [0],
#  'best': [0],
#  'be': [0, 1],
#  'reading': [0],
#  'different': [0, 1],
#  'includes': [0],
#  'misunderstand': [0],
#  'they': [0, 1],
#  'obvious': [0],
#  'scholars': [0],
#  'sea': [0],
#  'it': [0, 1],
#  'material': [0],
#  'newspapers': [0],
#  'sign': [0],
#  're': [0, 1],
#  'thus': [0],
#  'commentaries': [0],
#  'lurking': [0],
#  'proceeded': [0],
#  'as': [0, 1],
#  'were': [0, 1],
#  'tend': [0],
#  'to': [0, 1],
#  'issues': [0],
#  'emphasized': [0],
#  'various': [0],
#  'when': [0, 1],
#  'did': [0],
#  "you're": [0],
#  'too': [0, 1],
#  'present': [0],
#  'significant': [0],
#  'ot': [0],
#  'nntp': [0],
#  'the': [0, 1],
#  'lines': [0, 1],
#  'what': [0, 1],
#  'dead': [0],
#  'predating': [0],
#  'jewish': [0],
#  'was': [0, 1],
#  'where': [0],
#  'sgi': [0],
#  'prone': [0],
#  'satanic': [0],
#  'had': [0],
#  'vary': [0],
#  'other': [0, 1],
#  'subject': [0, 1],
#  'signifcant': [0],
#  'all': [0, 1],
#  'learn': [0],
#  'writes': [0, 1],
#  'extra': [0],
#  'posting': [0],
#  'mimsy': [0],
#  'i': [0, 1],
#  'organization': [0, 1],
#  'newspaper': [0],
#  'fragments': [0],
#  'sizes': [0],
#  '56': [0],
#  'variations': [0],
#  'books': [0],
#  'headline': [0],
#  'are': [0, 1],
#  'does': [0, 1],
#  'my': [0, 1],
#  'add': [0],
#  'isaiah': [0],
#  'from': [0, 1],
#  'error': [0, 1],
#  'of': [0, 1],
#  'notoriously': [0],
#  'tradition': [0],
#  'important': [0],
#  'distribution': [0],
#  'article': [0],
#  'so': [0, 1],
#  'took': [0],
#  'interests': [0],
#  'past': [0],
#  'ignorant': [0],
#  'kind': [0, 1],
#  'charley': [0],
#  'exclude': [0],
#  'almost': [0, 1],
#  'livesey': [0],
#  'differs': [0],
#  'little': [0],
#  'places': [0],
#  'idea': [0, 1],
#  'in': [0, 1],
#  'read': [0],
#  'second': [0],
#  'versions': [0],
#  'antecdent': [0],
#  'hey': [0],
#  'exaggeration': [0],
#  'unlike': [0],
#  "hasn't": [0],
#  'targums': [0],
#  'copied': [0],
#  'faithfully': [0],
#  'copy': [0],
#  'fixing': [0],
#  'that': [0, 1],
#  'really': [1],
#  'activity': [1],
#  'andtbacka': [1],
#  'exists': [1],
#  'deletia': [1],
#  'provably': [1],
#  'single': [1],
#  'object': [1],
#  'less': [1],
#  '_exactly_': [1],
#  'inform': [1],
#  'function': [1],
#  'look': [1],
#  'tried': [1],
#  "doesn't": [1],
#  'how': [1],
#  'manner': [1],
#  '21': [1],
#  'never': [1],
#  'assert': [1],
#  'say': [1],
#  'functional': [1],
#  'vms': [1],
#  'case': [1],
#  'come': [1],
#  'speaker': [1],
#  'given': [1],
#  'validity': [1],
#  'hypotheses': [1],
#  'biblical': [1],
#  'gmt': [1],
#  'statements': [1],
#  'off': [1],
#  'errors': [1],
#  'task': [1],
#  'your': [1],
#  'into': [1],
#  'word': [1],
#  "uucp's": [1],
#  'bars': [1],
#  'ours': [1],
#  'results': [1],
#  'think': [1],
#  'effect': [1],
#  "haven't": [1],
#  'objectively': [1],
#  'base': [1],
#  '09': [1],
#  '1993': [1],
#  'evidence': [1],
#  'sharp': [1],
#  'abo': [1],
#  'easiest': [1],
#  'conducted': [1],
#  'hard': [1],
#  'yes': [1],
#  'consistent': [1],
#  'opinions': [1],
#  'with': [1],
#  'nerves': [1],
#  'extreme': [1],
#  'measuring': [1],
#  'uucp': [1],
#  'them': [1],
#  'seems': [1],
#  'usage': [1],
#  'example': [1],
#  'english': [1],
#  'refute': [1],
#  'might': [1],
#  'precisely': [1],
#  'predicted': [1],
#  'consistently': [1],
#  'result': [1],
#  'anything': [1],
#  'record': [1],
#  'achieve': [1],
#  'even': [1],
#  'suitable': [1],
#  'simple': [1],
#  'mats': [1],
#  'things': [1],
#  'may': [1],
#  'within': [1],
#  'fine': [1],
#  'mandtbacka': [1],
#  '2000': [1],
#  'belief': [1],
#  'should': [1],
#  'map': [1],
#  'imaginable': [1],
#  'both': [1],
#  'universae': [1],
#  'dislike': [1],
#  'd012s658': [1],
#  'you': [1],
#  'random': [1],
#  'claiming': [1],
#  '151': [1],
#  'problem': [1],
#  'prediction': [1],
#  'individual': [1],
#  'immutable': [1],
#  'ballgame': [1],
#  'fi': [1],
#  'amount': [1],
#  'contradict': [1],
#  'sure': [1],
#  'implications': [1],
#  's': [1],
#  'blatant': [1],
#  'changed': [1],
#  'goal': [1],
#  'such': [1],
#  'scientific': [1],
#  'murder': [1],
#  "i'll": [1],
#  'clearly': [1],
#  'seemingly': [1],
#  'empirical': [1],
#  'calculations': [1],
#  'creationist': [1],
#  'islamic': [1],
#  'wrong': [1],
#  'need': [1],
#  'me': [1],
#  'wrote': [1],
#  'something': [1],
#  'depend': [1],
#  'saying': [1],
#  'being': [1],
#  'track': [1],
#  'seldom': [1],
#  'christian': [1],
#  "humanity's": [1],
#  'assumes': [1],
#  'painkillers': [1],
#  "_you're_": [1],
#  'will': [1],
#  'finabo': [1],
#  "rat's": [1],
#  'logically': [1],
#  'opinion': [1],
#  'another': [1],
#  'cosmology': [1],
#  'sort': [1],
#  "that'll": [1],
#  'thing': [1],
#  'more': [1],
#  'mean': [1],
#  'still': [1],
#  'stone': [1],
#  'care': [1],
#  'imagine': [1],
#  'circumstances': [1],
#  'measurement': [1],
#  'frank': [1],
#  'always': [1],
#  'times': [1],
#  'unorganized': [1],
#  'indeed': [1],
#  'verified': [1],
#  'ideas': [1],
#  'question': [1],
#  'misunderstood': [1],
#  'verify': [1],
#  'members': [1],
#  'semantics': [1],
#  'native': [1],
#  'basis': [1],
#  'assumption': [1],
#  'ultimate': [1],
#  'mass': [1],
#  'their': [1],
#  'then': [1],
#  'above': [1],
#  'would': [1],
#  'logical': [1],
#  'under': [1],
#  'mchp': [1],
#  'guess': [1],
#  'albeit': [1],
#  "we'd": [1],
#  'apr': [1],
#  'method': [1],
#  'work': [1],
#  'those': [1],
#  'same': [1],
#  'put': [1],
#  'news': [1],
#  'get': [1],
#  'secondly': [1],
#  'pain': [1],
#  "don't": [1],
#  'cases': [1],
#  'debating': [1],
#  'please': [1],
#  'existence': [1],
#  'wiped': [1],
#  'gravitate': [1],
#  'uninc': [1],
#  'difference': [1],
#  'own': [1],
#  'non': [1],
#  'quibble': [1],
#  'true': [1],
#  '24': [1],
#  'agree': [1],
#  'identical': [1],
#  'horus': [1],
#  'begging': [1],
#  'ages': [1],
#  'de': [1],
#  'sticking': [1],
#  'amazed': [1],
#  'enlighten': [1],
#  'proving': [1],
#  '38': [1],
#  "i'm": [1],
#  'facts': [1],
#  'stop': [1],
#  'internally': [1],
#  'noticed': [1],
#  'through': [1],
#  'independent': [1],
#  'most': [1],
#  'tasks': [1],
#  'than': [1],
#  "i'd": [1],
#  '43': [1],
#  'matrilineal': [1],
#  'society': [1],
#  'oxymoron': [1],
#  'codes': [1],
#  'values': [1],
#  'sni': [1],
#  'way': [1],
#  'hfj': [1],
#  'ap': [1],
#  'self': [1],
#  'polynesian': [1],
#  'out': [1],
#  'lend': [1],
#  'like': [1],
#  'individuals': [1],
#  'usenet': [1],
#  'give': [1],
#  'take': [1],
#  'power': [1],
#  'pick': [1],
#  'neural': [1],
#  'astronomy': [1],
#  'changes': [1],
#  'claim': [1],
#  'areas': [1],
#  'tested': [1],
#  'many': [1],
#  'lot': [1],
#  'mine': [1],
#  'until': [1],
#  'compute': [1],
#  'heard': [1],
#  'ponder': [1],
#  'perfectly': [1],
#  'correct': [1],
#  'subjective': [1],
#  'line': [1],
#  'physical': [1],
#  'down': [1],
#  'reason': [1],
#  'applied': [1],
#  'definition': [1],
#  'morality': [1],
#  'side': [1],
#  'drift': [1],
#  '1r34n3': [1],
#  'sometimes': [1],
#  'speak': [1],
#  'performs': [1],
#  'much': [1],
#  'longer': [1],
#  'however': [1],
#  '_always_': [1],
#  'systems': [1],
#  'elsewhere': [1],
#  'towards': [1],
#  'assuming': [1],
#  'credence': [1],
#  'suddenly': [1],
#  'thereby': [1],
#  'least': [1],
#  'direct': [1],
#  'message': [1],
#  'age': [1],
#  "can't": [1],
#  'showing': [1],
#  'make': [1],
#  'x': [1],
#  'beyond': [1],
#  'statement': [1],
#  'purposes': [1],
#  'fixed': [1],
#  'testing': [1],
#  'reader': [1],
#  'largish': [1],
#  'roughly': [1],
#  'better': [1],
#  'opposed': [1],
#  'makes': [1],
#  'emirically': [1],
#  'anybody': [1],
#  'if': [1],
#  'universe': [1],
#  'insane': [1],
#  'value': [1],
#  'reality': [1],
#  'see': [1],
#  'conclude': [1],
#  'societies': [1],
#  'spaniards': [1],
#  'luck': [1],
#  'together': [1],
#  'loss': [1],
#  'detail': [1],
#  'young': [1],
#  'can': [1],
#  'moral': [1],
#  'tests': [1],
#  'wish': [1],
#  'stick': [1],
#  'besides': [1],
#  'who': [1],
#  'apologies': [1],
#  'he': [1],
#  'context': [1],
#  'hypothesis': [1],
#  'yet': [1],
#  'defined': [1],
#  'calculating': [1],
#  'or': [1],
#  'else': [1],
#  "that's": [1],
#  'objective': [1],
#  'bad': [1],
#  'human': [1],
#  "'incorrect'": [1],
#  "hadn't": [1],
#  'beings': [1],
#  'footballs': [1],
#  'seem': [1],
#  "people's": [1],
#  'quite': [1],
#  'reply': [1],
#  '_real_': [1],
#  'debate': [1],
#  'one': [1],
#  'ass': [1],
#  'after': [1],
#  'our': [1],
#  'performing': [1],
#  'system': [1],
#  'beliefs': [1],
#  'means': [1],
#  'fully': [1],
#  'hir': [1],
#  'doing': [1],
#  'matter': [1],
#  'change': [1],
#  'hitting': [1],
#  'lead': [1],
#  '1': [1],
#  'useless': [1],
#  'just': [1],
#  'its': [1],
#  'exist': [1],
#  'quantify': [1],
#  'disclaimer': [1],
#  'aztecs': [1],
#  'good': [1],
#  'particular': [1],
#  '_can_': [1],
#  'wildly': [1],
#  'could': [1],
#  'postings': [1],
#  'observed': [1],
#  'ever': [1],
#  'assume': [1],
#  'producing': [1],
#  'humanity': [1],
#  "it's": [1],
#  'test': [1],
#  'desks': [1],
#  'accuracy': [1],
#  'label': [1],
#  "i've": [1],
#  'hold': [1],
#  'positive': [1],
#  'worse': [1],
#  'years': [1],
#  'thought': [1]}

# %%
mySearcher.searchOneOf(['mangoe', 'why']), mySearcher.searchAllOf(['mangoe', 'why'])
# Out:
# (['./20news-bydate-test/alt.atheism/53420',
#   './20news-bydate-test/alt.atheism/53639'],
#  ['./20news-bydate-test/alt.atheism/53420'])
